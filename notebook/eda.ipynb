# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("IndianFlightdata - Sheet1.csv")
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df[df["Route"].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %%
df[df["Total_Stops"].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %%
df.dropna()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df["date"]=df["Date_of_Journey"].str.split("/").str[0]
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price date
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302   01

# %%
df["month"]=df["Date_of_Journey"].str.split("/").str[1]
df["year"]=df["Date_of_Journey"].str.split("/").str[2]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302   01
#
#   month  year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# ...

# %%
df.drop("Date_of_Journey",axis=1,inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price date month  year
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897   24    03  2019
# 1         13:15   7h 25m     2 stops         No info   7662    1    05  2019
# 2  04:25 10 Jun      19h     2 stops         No info  13882    9    06  2019
# 3         23:30   5h 25m      1 stop         No info   6218   12    05  2019
# 4         21:35   4h 45m      1 stop         No info  13302   01    03  2019

# %%
df["dep_hrs"]=df["Dep_Time"].str.split(":").str[0]
df["dep_min"]=df["Dep_Time"].str.split(":").str[1]

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price date month  year  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897   24    03  2019
# 1         13:15   7h 25m     2 stops         No info   7662    1    05  2019
# 2  04:25 10 Jun      19h     2 stops         No info  13882    9    06  2019
# 3         23:30   5h 25m      1 stop         No info   6218   12    05  2019
# 4         21:35   4h 45m      1 stop         No info  13302   01    03  2019
#
#   dep_hrs dep_min
# 0      22      20
# 1      05      50
# 2      09      25
# ...

# %%
df.drop("Dep_Time",axis=1,inplace=True)

# %%
df[["month","date","year","dep_hrs","dep_min"]]=df[["month","date","year","dep_hrs","dep_min"]].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Arrival_Time     10683 non-null  object
#  5   Duration         10683 non-null  object
#  6   Total_Stops      10682 non-null  object
#  7   Additional_Info  10683 non-null  object
#  8   Price            10683 non-null  int64
#  9   date             10683 non-null  int64
#  10  month            10683 non-null  int64
#  11  year             10683 non-null  int64
#  12  dep_hrs          10683 non-null  int64
#  13  dep_min          10683 non-null  int64
# dtypes: int64(6), object(8)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price  date  month  year  dep_hrs  \
# 0   2h 50m    non-stop         No info   3897    24      3  2019       22
# 1   7h 25m     2 stops         No info   7662     1      5  2019        5
# 2      19h     2 stops         No info  13882     9      6  2019        9
# 3   5h 25m      1 stop         No info   6218    12      5  2019       18
# 4   4h 45m      1 stop         No info  13302     1      3  2019       16
#
#    dep_min
# 0       20
# 1       50
# 2       25
# 3        5
# 4       50

# %%
df["duration_hours"]=df["Duration"].str.split("h").str[0]
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price  date  month  year  dep_hrs  \
# 0   2h 50m    non-stop         No info   3897    24      3  2019       22
# 1   7h 25m     2 stops         No info   7662     1      5  2019        5
# 2      19h     2 stops         No info  13882     9      6  2019        9
# 3   5h 25m      1 stop         No info   6218    12      5  2019       18
# 4   4h 45m      1 stop         No info  13302     1      3  2019       16
#
#    dep_min duration_hours
# 0       20              2
# ...

# %%
df["duration_min"]=df["Duration"].str.split(" ").str[1]
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price  date  month  year  dep_hrs  \
# 0   2h 50m    non-stop         No info   3897    24      3  2019       22
# 1   7h 25m     2 stops         No info   7662     1      5  2019        5
# 2      19h     2 stops         No info  13882     9      6  2019        9
# 3   5h 25m      1 stop         No info   6218    12      5  2019       18
# 4   4h 45m      1 stop         No info  13302     1      3  2019       16
#
#    dep_min duration_hours duration_min
# ...

# %%
df["duration_min"]=df["duration_min"].str.split("m").str[0]

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price  date  month  year  dep_hrs  \
# 0   2h 50m    non-stop         No info   3897    24      3  2019       22
# 1   7h 25m     2 stops         No info   7662     1      5  2019        5
# 2      19h     2 stops         No info  13882     9      6  2019        9
# 3   5h 25m      1 stop         No info   6218    12      5  2019       18
# 4   4h 45m      1 stop         No info  13302     1      3  2019       16
#
#    dep_min duration_hours duration_min
# ...

# %%
df[df["duration_min"].isnull()]
# Out:
#                  Airline    Source Destination                        Route  \
# 2            Jet Airways     Delhi      Cochin        DEL → LKO → BOM → COK
# 18             Air India     Delhi      Cochin        DEL → CCU → BOM → COK
# 33           Jet Airways     Delhi      Cochin        DEL → NAG → BOM → COK
# 44     Multiple carriers     Delhi      Cochin              DEL → BOM → COK
# 53                IndiGo  Banglore       Delhi                    BLR → DEL
# ...                  ...       ...         ...                          ...
# 10591        Jet Airways     Delhi      Cochin        DEL → ATQ → BOM → COK
# 10638        Jet Airways  Banglore   New Delhi              BLR → BOM → DEL
# 10639          Air India     Delhi      Cochin  DEL → RPR → NAG → BOM → COK
# 10673        Jet Airways     Delhi      Cochin        DEL → AMD → BOM → COK
# 10680        Jet Airways  Banglore       Delhi                    BLR → DEL
#
# ...

# %%
df["duration_min"]=df["duration_min"].fillna(0)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price  date  month  year  dep_hrs  \
# 0   2h 50m    non-stop         No info   3897    24      3  2019       22
# 1   7h 25m     2 stops         No info   7662     1      5  2019        5
# 2      19h     2 stops         No info  13882     9      6  2019        9
# 3   5h 25m      1 stop         No info   6218    12      5  2019       18
# 4   4h 45m      1 stop         No info  13302     1      3  2019       16
#
#    dep_min duration_hours duration_min
# ...

# %%
df[df["duration_min"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Route, Arrival_Time, Duration, Total_Stops, Additional_Info, Price, date, month, year, dep_hrs, dep_min, duration_hours, duration_min]
# Index: []

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price  date  month  year  dep_hrs  \
# 0   2h 50m    non-stop         No info   3897    24      3  2019       22
# 1   7h 25m     2 stops         No info   7662     1      5  2019        5
# 2      19h     2 stops         No info  13882     9      6  2019        9
# 3   5h 25m      1 stop         No info   6218    12      5  2019       18
# 4   4h 45m      1 stop         No info  13302     1      3  2019       16
#
#    dep_min duration_hours duration_min
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Arrival_Time     10683 non-null  object
#  5   Duration         10683 non-null  object
#  6   Total_Stops      10682 non-null  object
#  7   Additional_Info  10683 non-null  object
#  8   Price            10683 non-null  int64
#  9   date             10683 non-null  int64
#  10  month            10683 non-null  int64
#  11  year             10683 non-null  int64
#  12  dep_hrs          10683 non-null  int64
#  13  dep_min          10683 non-null  int64
#  14  duration_hours   10683 non-null  object
#  15  duration_min     10683 non-null  object
# dtypes: int64(6), object(10)
# ...

# %%
df[df["duration_hours"]=="5m"]
# Out:
#         Airline  Source Destination                  Route Arrival_Time  \
# 6474  Air India  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD        16:55
#
#      Duration Total_Stops Additional_Info  Price  date  month  year  dep_hrs  \
# 6474       5m     2 stops         No info  17327     6      3  2019       16
#
#       dep_min duration_hours duration_min
# 6474       50             5m            0

# %%
df.drop(6474,inplace=True)

# %%
df[["duration_hours","duration_min"]]=df[["duration_hours","duration_min"]].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10682 non-null  object
#  1   Source           10682 non-null  object
#  2   Destination      10682 non-null  object
#  3   Route            10681 non-null  object
#  4   Arrival_Time     10682 non-null  object
#  5   Duration         10682 non-null  object
#  6   Total_Stops      10681 non-null  object
#  7   Additional_Info  10682 non-null  object
#  8   Price            10682 non-null  int64
#  9   date             10682 non-null  int64
#  10  month            10682 non-null  int64
#  11  year             10682 non-null  int64
#  12  dep_hrs          10682 non-null  int64
#  13  dep_min          10682 non-null  int64
#  14  duration_hours   10682 non-null  int64
#  15  duration_min     10682 non-null  int64
# dtypes: int64(8), object(8)
# memory usage: 1.4+ MB

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price  date  month  year  dep_hrs  \
# 0   2h 50m    non-stop         No info   3897    24      3  2019       22
# 1   7h 25m     2 stops         No info   7662     1      5  2019        5
# 2      19h     2 stops         No info  13882     9      6  2019        9
# 3   5h 25m      1 stop         No info   6218    12      5  2019       18
# 4   4h 45m      1 stop         No info  13302     1      3  2019       16
#
#    dep_min  duration_hours  duration_min
# ...

# %%
df.drop("Duration",inplace=True,axis=1)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Total_Stops Additional_Info  Price  date  month  year  dep_hrs  dep_min  \
# 0    non-stop         No info   3897    24      3  2019       22       20
# 1     2 stops         No info   7662     1      5  2019        5       50
# 2     2 stops         No info  13882     9      6  2019        9       25
# 3      1 stop         No info   6218    12      5  2019       18        5
# 4      1 stop         No info  13302     1      3  2019       16       50
#
#    duration_hours  duration_min
# 0               2            50
# ...

# %%
df["arrival_hr"]=df["Arrival_Time"].str.split(":").str[0]
df["arrival_min"]=df["Arrival_Time"].str.split(":").str[1]

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Total_Stops Additional_Info  Price  date  month  year  dep_hrs  dep_min  \
# 0    non-stop         No info   3897    24      3  2019       22       20
# 1     2 stops         No info   7662     1      5  2019        5       50
# 2     2 stops         No info  13882     9      6  2019        9       25
# 3      1 stop         No info   6218    12      5  2019       18        5
# 4      1 stop         No info  13302     1      3  2019       16       50
#
#    duration_hours  duration_min arrival_hr arrival_min
# ...

# %%
df["arrival_min"]=df["arrival_min"].str.split(" ").str[0]

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Total_Stops Additional_Info  Price  date  month  year  dep_hrs  dep_min  \
# 0    non-stop         No info   3897    24      3  2019       22       20
# 1     2 stops         No info   7662     1      5  2019        5       50
# 2     2 stops         No info  13882     9      6  2019        9       25
# 3      1 stop         No info   6218    12      5  2019       18        5
# 4      1 stop         No info  13302     1      3  2019       16       50
#
#    duration_hours  duration_min arrival_hr arrival_min
# ...

# %%
df["arrival_date"]=df["Arrival_Time"].str.split(" ").str[1]

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Total_Stops Additional_Info  Price  date  month  year  dep_hrs  dep_min  \
# 0    non-stop         No info   3897    24      3  2019       22       20
# 1     2 stops         No info   7662     1      5  2019        5       50
# 2     2 stops         No info  13882     9      6  2019        9       25
# 3      1 stop         No info   6218    12      5  2019       18        5
# 4      1 stop         No info  13302     1      3  2019       16       50
#
#    duration_hours  duration_min arrival_hr arrival_min arrival_date
# ...

# %%
df["arrival_date"]=df["arrival_date"].fillna(0)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Total_Stops Additional_Info  Price  date  month  year  dep_hrs  dep_min  \
# 0    non-stop         No info   3897    24      3  2019       22       20
# 1     2 stops         No info   7662     1      5  2019        5       50
# 2     2 stops         No info  13882     9      6  2019        9       25
# 3      1 stop         No info   6218    12      5  2019       18        5
# 4      1 stop         No info  13302     1      3  2019       16       50
#
#    duration_hours  duration_min arrival_hr arrival_min arrival_date
# ...

# %%
df.drop("Arrival_Time",inplace=True,axis=1)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info  Price  date  month  year  dep_hrs  dep_min  duration_hours  \
# 0         No info   3897    24      3  2019       22       20               2
# 1         No info   7662     1      5  2019        5       50               7
# 2         No info  13882     9      6  2019        9       25              19
# 3         No info   6218    12      5  2019       18        5               5
# 4         No info  13302     1      3  2019       16       50               4
#
#    duration_min arrival_hr arrival_min arrival_date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10682 non-null  object
#  1   Source           10682 non-null  object
#  2   Destination      10682 non-null  object
#  3   Route            10681 non-null  object
#  4   Total_Stops      10681 non-null  object
#  5   Additional_Info  10682 non-null  object
#  6   Price            10682 non-null  int64
#  7   date             10682 non-null  int64
#  8   month            10682 non-null  int64
#  9   year             10682 non-null  int64
#  10  dep_hrs          10682 non-null  int64
#  11  dep_min          10682 non-null  int64
#  12  duration_hours   10682 non-null  int64
#  13  duration_min     10682 non-null  int64
#  14  arrival_hr       10682 non-null  object
#  15  arrival_min      10682 non-null  object
#  16  arrival_date     10682 non-null  object
# ...

# %%
df[["arrival_hr","arrival_min","arrival_date"]]=df[["arrival_hr","arrival_min","arrival_date"]].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10682 non-null  object
#  1   Source           10682 non-null  object
#  2   Destination      10682 non-null  object
#  3   Route            10681 non-null  object
#  4   Total_Stops      10681 non-null  object
#  5   Additional_Info  10682 non-null  object
#  6   Price            10682 non-null  int64
#  7   date             10682 non-null  int64
#  8   month            10682 non-null  int64
#  9   year             10682 non-null  int64
#  10  dep_hrs          10682 non-null  int64
#  11  dep_min          10682 non-null  int64
#  12  duration_hours   10682 non-null  int64
#  13  duration_min     10682 non-null  int64
#  14  arrival_hr       10682 non-null  int64
#  15  arrival_min      10682 non-null  int64
#  16  arrival_date     10682 non-null  int64
# ...

# %%
df["Additional_Info"].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info  Price  date  month  year  dep_hrs  dep_min  duration_hours  \
# 0         No info   3897    24      3  2019       22       20               2
# 1         No info   7662     1      5  2019        5       50               7
# 2         No info  13882     9      6  2019        9       25              19
# 3         No info   6218    12      5  2019       18        5               5
# 4         No info  13302     1      3  2019       16       50               4
#
#    duration_min  arrival_hr  arrival_min  arrival_date
# ...

# %%
df["Total_Stops"].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
df["total_Stops"] = df["Total_Stops"].replace({"non-stop": 0,"1 stop": 1,"2 stops": 2,"3 stops": 3,"4 stops": 4})
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_11788\4228806137.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["total_Stops"] = df["Total_Stops"].replace({"non-stop": 0,"1 stop": 1,"2 stops": 2,"3 stops": 3,"4 stops": 4})

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info  Price  date  month  year  dep_hrs  dep_min  duration_hours  \
# 0         No info   3897    24      3  2019       22       20               2
# 1         No info   7662     1      5  2019        5       50               7
# 2         No info  13882     9      6  2019        9       25              19
# 3         No info   6218    12      5  2019       18        5               5
# 4         No info  13302     1      3  2019       16       50               4
#
# ...

# %%
df[df["total_Stops"].isnull()]
# Out:
#         Airline Source Destination Route Total_Stops Additional_Info  Price  \
# 9039  Air India  Delhi      Cochin   NaN         NaN         No info   7480
#
#       date  month  year  dep_hrs  dep_min  duration_hours  duration_min  \
# 9039     6      5  2019        9       45              23            40
#
#       arrival_hr  arrival_min  arrival_date  total_Stops
# 9039           9           25             7          NaN

# %%
df["total_Stops"]=df["total_Stops"].fillna(0)

# %%
df["total_Stops"].unique()
# Out:
# array([0., 2., 1., 3., 4.])

# %%
df["total_Stops"]=df["total_Stops"].astype(int)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info  Price  date  month  year  dep_hrs  dep_min  duration_hours  \
# 0         No info   3897    24      3  2019       22       20               2
# 1         No info   7662     1      5  2019        5       50               7
# 2         No info  13882     9      6  2019        9       25              19
# 3         No info   6218    12      5  2019       18        5               5
# 4         No info  13302     1      3  2019       16       50               4
#
# ...

# %%
df.drop("Total_Stops",inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10682 non-null  object
#  1   Source           10682 non-null  object
#  2   Destination      10682 non-null  object
#  3   Route            10681 non-null  object
#  4   Additional_Info  10682 non-null  object
#  5   Price            10682 non-null  int64
#  6   date             10682 non-null  int64
#  7   month            10682 non-null  int64
#  8   year             10682 non-null  int64
#  9   dep_hrs          10682 non-null  int64
#  10  dep_min          10682 non-null  int64
#  11  duration_hours   10682 non-null  int64
#  12  duration_min     10682 non-null  int64
#  13  arrival_hr       10682 non-null  int64
#  14  arrival_min      10682 non-null  int64
#  15  arrival_date     10682 non-null  int64
#  16  total_Stops      10682 non-null  int64
# ...

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Additional_Info  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL         No info
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         No info
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK         No info
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         No info
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         No info
#
#    Price  date  month  year  dep_hrs  dep_min  duration_hours  duration_min  \
# 0   3897    24      3  2019       22       20               2            50
# 1   7662     1      5  2019        5       50               7            25
# 2  13882     9      6  2019        9       25              19             0
# 3   6218    12      5  2019       18        5               5            25
# 4  13302     1      3  2019       16       50               4            45
#
# ...

# %%
df["Additional_Info"].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df["Additional_Info"] = df["Additional_Info"].replace("No info", "No Info")

# %%
df["Additional_Info"].unique()
# Out:
# array(['No Info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df.drop("Route", axis=1, inplace=True)

# %%
df_copy=df

# %%
df[["Airline","Source","Destination","Additional_Info"]] = \
df[["Airline","Source","Destination","Additional_Info"]].fillna("Unknown")

# %%
cols_to_encode = ["Airline", "Source", "Destination", "Additional_Info"]
df = pd.get_dummies(df, columns=cols_to_encode, drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 40 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Price                                         10682 non-null  int64
#  1   date                                          10682 non-null  int64
#  2   month                                         10682 non-null  int64
#  3   year                                          10682 non-null  int64
#  4   dep_hrs                                       10682 non-null  int64
#  5   dep_min                                       10682 non-null  int64
#  6   duration_hours                                10682 non-null  int64
#  7   duration_min                                  10682 non-null  int64
#  8   arrival_hr                                    10682 non-null  int64
# ...

# %%
df.to_csv("airlines_clean_readable.csv", index=False)

# %%
df_copy
# Out:
#            Airline    Source Destination Additional_Info  Price  date  month  \
# 0           IndiGo  Banglore   New Delhi         No Info   3897    24      3
# 1        Air India   Kolkata    Banglore         No Info   7662     1      5
# 2      Jet Airways     Delhi      Cochin         No Info  13882     9      6
# 3           IndiGo   Kolkata    Banglore         No Info   6218    12      5
# 4           IndiGo  Banglore   New Delhi         No Info  13302     1      3
# ...            ...       ...         ...             ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore         No Info   4107     9      4
# 10679    Air India   Kolkata    Banglore         No Info   4145    27      4
# 10680  Jet Airways  Banglore       Delhi         No Info   7229    27      4
# 10681      Vistara  Banglore   New Delhi         No Info  12648     1      3
# 10682    Air India     Delhi      Cochin         No Info  11753     9      5
#
# ...

# %%
## plot density plot for all feature
plt.style.use('seaborn-v0_8')
df_copy.hist(bins=50,figsize=(20,15))
plt.show()

# %%
df_copy.corr(numeric_only=True)
# Out:
#                    Price      date     month  year   dep_hrs   dep_min  \
# Price           1.000000 -0.153619 -0.103431   NaN  0.006718 -0.024726
# date           -0.153619  1.000000 -0.038505   NaN  0.002271 -0.008149
# month          -0.103431 -0.038505  1.000000   NaN  0.039201 -0.059062
# year                 NaN       NaN       NaN   NaN       NaN       NaN
# dep_hrs         0.006718  0.002271  0.039201   NaN  1.000000 -0.024887
# dep_min        -0.024726 -0.008149 -0.059062   NaN -0.024887  1.000000
# duration_hours  0.508985 -0.022283  0.016012   NaN  0.002852 -0.021795
# duration_min   -0.124673 -0.009112 -0.041076   NaN -0.023669  0.092741
# arrival_hr      0.024203 -0.003160 -0.003889   NaN  0.005193  0.043008
# arrival_min    -0.086489 -0.017362 -0.100399   NaN  0.067816 -0.017833
# arrival_date    0.217768  0.365315  0.011810   NaN  0.385260 -0.020616
# total_Stops     0.603776 -0.009206  0.054603   NaN -0.061511 -0.002966
#
# ...

# %%
df_copy.drop("year",inplace=True,axis=1)

# %%
corr=df_copy.corr(numeric_only=True)

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
X=df.drop("Price",axis=1)
y=df["Price"]

# %%
X
# Out:
#        date  month  year  dep_hrs  dep_min  duration_hours  duration_min  \
# 0        24      3  2019       22       20               2            50
# 1         1      5  2019        5       50               7            25
# 2         9      6  2019        9       25              19             0
# 3        12      5  2019       18        5               5            25
# 4         1      3  2019       16       50               4            45
# ...     ...    ...   ...      ...      ...             ...           ...
# 10678     9      4  2019       19       55               2            30
# 10679    27      4  2019       20       45               2            35
# 10680    27      4  2019        8       20               3             0
# 10681     1      3  2019       11       30               2            40
# 10682     9      5  2019       10       55               8            20
#
#        arrival_hr  arrival_min  arrival_date  ...  Destination_Kolkata  \
# ...

# %%
X.drop("year",axis=1)
# Out:
#        date  month  dep_hrs  dep_min  duration_hours  duration_min  \
# 0        24      3       22       20               2            50
# 1         1      5        5       50               7            25
# 2         9      6        9       25              19             0
# 3        12      5       18        5               5            25
# 4         1      3       16       50               4            45
# ...     ...    ...      ...      ...             ...           ...
# 10678     9      4       19       55               2            30
# 10679    27      4       20       45               2            35
# 10680    27      4        8       20               3             0
# 10681     1      3       11       30               2            40
# 10682     9      5       10       55               8            20
#
#        arrival_hr  arrival_min  arrival_date  total_Stops  ...  \
# 0               1           10            22            0  ...
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 1.58667486,  1.10467572,  0.        , ...,  0.52488403,
#         -0.175333  , -0.01156553],
#        [ 0.87667838,  1.10467572,  0.        , ...,  0.52488403,
#         -0.175333  , -0.01156553],
#        [ 1.58667486,  0.24661834,  0.        , ...,  0.52488403,
#         -0.175333  , -0.01156553],
#        ...,
#        [ 0.16668189,  0.24661834,  0.        , ...,  0.52488403,
#         -0.175333  , -0.01156553],
#        [-1.25331108, -1.46949643,  0.        , ...,  0.52488403,
#         -0.175333  , -0.01156553],
#        [-1.48997658,  1.10467572,  0.        , ...,  0.52488403,
#         -0.175333  , -0.01156553]], shape=(7477, 39))

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(X_train_scaled,y_train)
y_pred=regression.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score,r2_score,mean_absolute_error
score=r2_score(y_test,y_pred)
score
# Out:
# 0.6960249990270284

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge=Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred=ridge.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print(score,mae)
plt.scatter(y_test,y_pred)
# Out:
# 0.6958448499224505 1755.6571004917485

# %%
from sklearn.linear_model import Lasso
lasso=Lasso()
lasso.fit(X_train_scaled,y_train)
lasso_pred=lasso.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print(score,mae)
# Out:
# 0.6958448499224505 1755.6571004917485

# %%
lasso.coef_
# Out:
# array([ -548.8287633 ,  -467.41957282,     0.        ,    84.23369026,
#          -38.18132544,    75.29073841,   -41.67239296,   -78.27761128,
#           41.71430798,    37.44565281,  1697.67509384,   635.44381646,
#           38.12821645,    89.14368847,  2947.84480474,  1019.49716689,
#         1266.27003918,   159.46342507,   -40.85965568,   -26.33020032,
#          432.44677347,    35.62227976,    -5.22989556,    85.57173687,
#           -0.        ,  -405.21411192,     0.        ,  -328.65687242,
#          -31.87848617,   -19.09175236,   366.20492878,    79.16951946,
#           73.31664203,   259.41451069,   -96.12494075, -3668.19364834,
#        -2420.69918023, -1059.70447658,   -28.72653856])

# %%
import pandas as pd

coef_df = pd.DataFrame({
    "feature": X.columns,
    "coef": lasso.coef_
})

coef_df["abs_coef"] = coef_df["coef"].abs()
coef_df.sort_values("abs_coef", ascending=False)
# Out:
#                                          feature         coef     abs_coef
# 35   Additional_Info_In-flight meal not included -3668.193648  3668.193648
# 14                           Airline_Jet Airways  2947.844805  2947.844805
# 36                       Additional_Info_No Info -2420.699180  2420.699180
# 10                                   total_Stops  1697.675094  1697.675094
# 16                     Airline_Multiple carriers  1266.270039  1266.270039
# 37  Additional_Info_No check-in baggage included -1059.704477  1059.704477
# 15                  Airline_Jet Airways Business  1019.497167  1019.497167
# 11                             Airline_Air India   635.443816   635.443816
# 0                                           date  -548.828763   548.828763
# 1                                          month  -467.419573   467.419573
# 20                               Airline_Vistara   432.446773   432.446773
# ...

# %%
from sklearn.linear_model import LassoCV
lassocv=LassoCV()
lassocv.fit(X_train_scaled,y_train)
lassocv_pred=lassocv.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print(score,mae)
# Out:
# 0.6958448499224505 1755.6571004917485

# %%
from sklearn.linear_model import RidgeCV
ridgecv=RidgeCV()
ridgecv.fit(X_train_scaled,y_train)
ridgecv_pred=ridgecv.predict(X_test_scaled)
mae_ridge=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print(score,mae_ridge)
# Out:
# 0.6958448499224505 1755.6571004917485
